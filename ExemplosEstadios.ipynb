# %% [markdown]
# <a href="https://colab.research.google.com/github/OffTAVs/ProjetoEstadiosFutebol/blob/main/ExemplosEstadios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.9 MB/s eta 0:00:00
# ...

# %%
#Baixando o data set em csv
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %%
#Convertendo csv em Data Frame Pandas
estadios_df = pd.read_csv(dataset)

# %%
#Visualizando os 5 primeiros regristros do DataFrame
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
#Convertendo em um dicionário
dicionario = estadios_df.to_dict('records')

# %%
#Visualizanado
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
# ...

# %%
#conexão ao Server Mongo
cliente = MongoClient("mongodb+srv://otaviobarbosa2004:123@clusterfatec.la45u.mongodb.net/?retryWrites=true&w=majority&appName=ClusterFatec")

# %%
#Seleciona a base de dados
db = cliente.get_database('futebol')

# %%
#Insere os documetos na nova base de dados
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('6715bcb9cfba29044709cd66'), ObjectId('6715bcb9cfba29044709cd67'), ObjectId('6715bcb9cfba29044709cd68'), ObjectId('6715bcb9cfba29044709cd69'), ObjectId('6715bcb9cfba29044709cd6a'), ObjectId('6715bcb9cfba29044709cd6b'), ObjectId('6715bcb9cfba29044709cd6c'), ObjectId('6715bcb9cfba29044709cd6d'), ObjectId('6715bcb9cfba29044709cd6e'), ObjectId('6715bcb9cfba29044709cd6f'), ObjectId('6715bcb9cfba29044709cd70'), ObjectId('6715bcb9cfba29044709cd71'), ObjectId('6715bcb9cfba29044709cd72'), ObjectId('6715bcb9cfba29044709cd73'), ObjectId('6715bcb9cfba29044709cd74'), ObjectId('6715bcb9cfba29044709cd75'), ObjectId('6715bcb9cfba29044709cd76'), ObjectId('6715bcb9cfba29044709cd77'), ObjectId('6715bcb9cfba29044709cd78'), ObjectId('6715bcb9cfba29044709cd79')], acknowledged=True)

# %%
#recuperando uma collection em uma varialvel
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['clusterfatec-shard-00-01.la45u.mongodb.net:27017', 'clusterfatec-shard-00-00.la45u.mongodb.net:27017', 'clusterfatec-shard-00-02.la45u.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterFatec', authsource='admin', replicaset='atlas-sei7kv-shard-0', tls=True), 'futebol'), 'estadios')

# %%
#visualizando o conteudo da variável estadios
list(estadios.find())
# Out:
# [{'_id': ObjectId('67119e1370ca5b6a6308918c'),
#   'nome': 'Vila Belmiro',
#   'capacidade': 21732,
#   'latitude': -23.57243,
#   'longitude': -46.20123},
#  {'_id': ObjectId('67119eea06d8b5495a7b5b92'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('67119eea06d8b5495a7b5b93'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('67119eea06d8b5495a7b5b94'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('67119eea06d8b5495a7b5b95'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('67119eea06d8b5495a7b5b96'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('67119eea06d8b5495a7b5b97'),
# ...

# %%
#Estabelecendo um ponto central do mapa
center_lat = -14.24007
center_lon = -53.18050

# %%
#Todos os dados dos estadios na variavel consulta
consulta = list(estadios.find())

# %%
#Converter em um Dataframe para vizualizar o mapa
df_convertido = pd.DataFrame(consulta)

# %%
#Imprime a primeira linha do DataFrame
df_convertido.iloc[0]
# Out:
# _id           67119e1370ca5b6a6308918c
# nome                      Vila Belmiro
# capacidade                       21732
# latitude                     -23.57243
# longitude                    -46.20123
# Name: 0, dtype: object

# %%
#Cria um mapa a partir do ponto central com 800x600
locationmap = folium.Map(location=[center_lat , center_lon], zoom_strat=5, width=800, height=600)

# %%
#Recuperando a quantidade de pontos
qtde = len(df_convertido)

# %%
qtde
# Out:
# 41

# %%
#Laço de repetição para marcar cada ponto
for i in range(qtde):
  lng = float(df_convertido.iloc[i]['longitude'])
  lat = float(df_convertido.iloc[i]['latitude'])
  descripition = 'Estádio: ' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
  folium.Marker( [ lat , lng ],
                popup= descripition,
                 icon=folium.Icon(color='red')).add_to(locationmap)

# %%
#Exibindo
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
